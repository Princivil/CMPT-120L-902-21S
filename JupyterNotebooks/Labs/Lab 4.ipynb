# %% [markdown]
# # Lab Four
# ---
#
# For this lab we're going to be messing around with Markdown!
#
# Our Goals are:
# - Using Markdown!
#
# I want you to describe to me your process of converting the assignment and making it DRY.
#
# Please show the ability to:
# - Make a header
# - Make a list (ordered or unordered)
# - Link the Markdown Guide from the lesson.
# - Artuculate your thought process.

# %% [markdown]
# # Lab 4 Explanantion
#
# ---
#
# Reference: [Markdown](https://www.markdownguide.org/)
# #
# #
# #### Wet Code Given:
#
# ```
# checking += (transations[0] * 0.85)
#     savings += (transations[0] * 0.15)
#
#     checking += transations[1]
#
#     checking += transations[2]
#
#     checking += transations[3]
#
#     checking += (transations[4] * 0.85)
#     savings += (transations[4] * 0.15)
#
#     checking += (transations[5] * 0.85)
#     savings += (transations[5] * 0.15)
#
#     checking += transations[6]
#
#     checking += transations[7]
#
#     checking += transations[8]
#
#     checking += transations[9]
#
#     checking += transations[10]
#
#     return checking, savings
# ```
# #
# #
# #
# In order to simplify this piece I considered:
# -
# -Repetition of when savings and checkings were partially deposited
#
# -When the payments were fully deposited to checkings
#
# Since the code required for each value within the list to be looped through, I made the loop travel through the length of the list so that the function could work for any amount of transactions.
# ```
#  for i in range(len(transactions)):
# ```
# #
# #
# #
# ```
# checking += (transations[i] * 0.85)
#     savings += (transations[i] * 0.15)
# ```
# I noticed this code above only repeated for certain elements within the list so I created an if statement within the loop that deposited the partial amounts to each account like so:
# ```
# if i == 0 or i==4 or i==5:
#             checking += (transations[i] * 0.85)
#             savings += (transations[i] * 0.15))
# ```
# #
# #
# #
# For any other value within the list, it was directly deposited to the checkings so I simply used an else statement:
# ```
# else:
#             checking += (transactions[i])
# ```
#
# The final end of the for each loop returned the value of the checkings and savings accounts.
# ```
# return checking, savings
# ```
#
# ### Final Dry Code:
#
# ```
# for i in range(len(transactions)):
#         if i == 0 or i==4 or i==5:
#             checking += (transations[i] * 0.85)
#             savings += (transations[i] * 0.15)
#         else:
#             checking += (transactions[i])
#     return checking, savings
# ```
